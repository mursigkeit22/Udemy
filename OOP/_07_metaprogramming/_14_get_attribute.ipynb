# %% [markdown]
# how does python access attributes in an object

# %%
class Person:
    pass

# %% [markdown]
# attribute's value can be in any number of places:
# - instance dict
# - class attribute
# - descriptor
# - in a parent class

# %% [markdown]
# `__getattribute__` bound method is called first, when we call person.name for example

# %% [markdown]
# we can override it by implementing `__getattribute__(self, name)`

# %% [markdown]
# usually we override `__getattr__` and not `__getattribute__`

# %% [markdown]
# `__getattr__` method is called by Python if `__getattribute__` cannot find the requested attribute and raises AttributeError

# %% [markdown]
# `__getattr__`'s default implementation only raises AttributeError

# %% [markdown]
# if we call `__getattribute__` ourselves and it fails, `__getattr__` doesn't get called by itself. we may want to call it specifically

# %% [markdown]
# _see lookup resolution in download folder_

# %% [markdown]
# `__getattribute__` and `__getattr__` are instance methods.

# %% [markdown]
# how do we override class attribute access? using metaclass.

# %%
p = Person()
try:
    p.name
except AttributeError as ex:
    print(ex)
# Out:
# 'Person' object has no attribute 'name'

# %% [markdown]
# let's override getattr method. `__getattr__` is called when `__getattribute__` returns an error

# %%
class Person:
    def __getattr__(self, name):
        print(f"__getattribute__ did not find {name}")
        return "not found!"

# %%
p = Person()

p.name
# Out:
# __getattribute__ did not find name
# 'not found!'

# %% [markdown]
# we should avoid infinite recursions

# %%
class Person:
    def __getattr__(self, name):
        print(f"__getattribute__ did not find {name}")
        alt_name = "_" + name
        if getattr(self, alt_name, None) is None:
            return getattr(self, alt_name)
        else:
            raise AttributeError(f"could not find {name} or {alt_name}")

# %%
p = Person()

p.age
# Out:
# __getattribute__ did not find age
# __getattribute__ did not find _age
# __getattribute__ did not find __age
# __getattribute__ did not find ___age
# __getattribute__ did not find ____age
# __getattribute__ did not find _____age
# __getattribute__ did not find ______age
# __getattribute__ did not find _______age
# __getattribute__ did not find ________age
# __getattribute__ did not find _________age
# __getattribute__ did not find __________age
# __getattribute__ did not find ___________age
# __getattribute__ did not find ____________age
# __getattribute__ did not find _____________age
# __getattribute__ did not find ______________age
# __getattribute__ did not find _______________age
# __getattribute__ did not find ________________age
# __getattribute__ did not find _________________age
# __getattribute__ did not find __________________age
# __getattribute__ did not find ___________________age
# __getattribute__ did not find ____________________age
# __getattribute__ did not find _____________________age
# __getattribute__ did not find ______________________age
# __getattribute__ did not find _______________________age
# __getattribute__ did not find ________________________age
# __getattribute__ did not find _________________________age
# __getattribute__ did not find __________________________age
# __getattribute__ did not find ___________________________age
# __getattribute__ did not find ____________________________age
# __getattribute__ did not find _____________________________age
# __getattribute__ did not find ______________________________age
# __getattribute__ did not find _______________________________age
# __getattribute__ did not find ________________________________age
# __getattribute__ did not find _________________________________age
# __getattribute__ did not find __________________________________age
# __getattribute__ did not find ___________________________________age
# __getattribute__ did not find ____________________________________age
# __getattribute__ did not find _____________________________________age
# __getattribute__ did not find ______________________________________age
# __getattribute__ did not find _______________________________________age
# __getattribute__ did not find ________________________________________age
# __getattribute__ did not find _________________________________________age
# __getattribute__ did not find __________________________________________age
# __getattribute__ did not find ___________________________________________age
# __getattribute__ did not find ____________________________________________age
# __getattribute__ did not find _____________________________________________age
# __getattribute__ did not find ______________________________________________age
# __getattribute__ did not find _______________________________________________age
# __getattribute__ did not find ________________________________________________age
# __getattribute__ did not find _________________________________________________age
# __getattribute__ did not find __________________________________________________age
# __getattribute__ did not find ___________________________________________________age
# __getattribute__ did not find ____________________________________________________age
# __getattribute__ did not find _____________________________________________________age
# __getattribute__ did not find ______________________________________________________age
# __getattribute__ did not find _______________________________________________________age
# __getattribute__ did not find ________________________________________________________age
# __getattribute__ did not find _________________________________________________________age
# __getattribute__ did not find __________________________________________________________age
# __getattribute__ did not find ___________________________________________________________age
# __getattribute__ did not find ____________________________________________________________age
# __getattribute__ did not find _____________________________________________________________age
# __getattribute__ did not find ______________________________________________________________age
# __getattribute__ did not find _______________________________________________________________age
# __getattribute__ did not find ________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# ...
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# __getattribute__ did not find ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________age
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-7-b19c5f09ed26> in <module>
#       1 p = Person()
#       2
# ----> 3 p.age
#
# <ipython-input-5-52a2f63946a4> in __getattr__(self, name)
#       3         print(f"__getattribute__ did not find {name}")
#       4         alt_name = "_" + name
# ----> 5         if getattr(self, alt_name, None) is None:
#       6             return getattr(self, alt_name)
#       7         else:
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-5-52a2f63946a4> in __getattr__(self, name)
#       3         print(f"__getattribute__ did not find {name}")
#       4         alt_name = "_" + name
# ----> 5         if getattr(self, alt_name, None) is None:
#       6             return getattr(self, alt_name)
#       7         else:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# let's fix it

# %%
class Person:
    def __getattr__(self, name):
        alt_name = "_" + name
        print(f"__getattribute__ did not find {name}, trying {alt_name}")
        try:
            return super().__getattribute__(alt_name) # we call __getattribute__ directly, 
        #so python will not call  __getattr__
        except AttributeError:
            raise AttributeError(f"could not find {name} or {alt_name}")

# %%
p = Person()

p.age
# Out:
# __getattribute__ did not find age, trying _age
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-407df25122bd> in __getattr__(self, name)
#       5         try:
# ----> 6             return super().__getattribute__(alt_name) # we call __getattribute__ directly,
#       7         #so python will not call  __getattr__
#
# AttributeError: 'Person' object has no attribute '_age'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b19c5f09ed26> in <module>
#       1 p = Person()
#       2
# ----> 3 p.age
#
# <ipython-input-8-407df25122bd> in __getattr__(self, name)
#       7         #so python will not call  __getattr__
#       8         except AttributeError:
# ----> 9             raise AttributeError(f"could not find {name} or {alt_name}")
#      10
#
# AttributeError: could not find age or _age

# %%
try:
    p.age
except AttributeError as err:
    print(err)
# Out:
# __getattribute__ did not find age, trying _age
# could not find age or _age

# %% [markdown]
# without try-except:

# %%
class Person:
    def __getattr__(self, name):
        alt_name = "_" + name
        print(f"__getattribute__ did not find {name}, trying {alt_name}")
        
        return super().__getattribute__(alt_name)

# %%
p = Person()

p.age
# not informative
# Out:
# __getattribute__ did not find age, trying _age
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b19c5f09ed26> in <module>
#       1 p = Person()
#       2
# ----> 3 p.age
#
# <ipython-input-11-228fb0f23d0a> in __getattr__(self, name)
#       4         print(f"__getattribute__ did not find {name}, trying {alt_name}")
#       5
# ----> 6         return super().__getattribute__(alt_name)
#       7
#
# AttributeError: 'Person' object has no attribute '_age'

# %%
class Person:
    def __init__(self, age):
        self._age = age
    
    def __getattr__(self, name):
        alt_name = "_" + name
        print(f"__getattribute__ did not find {name}, trying {alt_name}")
        try:
            return super().__getattribute__(alt_name) # we call __getattribute__ directly, 
        #so python will not call  __getattr__
        except AttributeError:
            raise AttributeError(f"could not find {name} or {alt_name}")

# %%
p = Person(43)

p.age
# Out:
# __getattribute__ did not find age, trying _age
# 43

# %%
p._age
# Out:
# 43

# %% [markdown]
# we may want to be able to access attributes of the class, even if they don't exist, like default dict

# %%
class DefaultClass:
    def __init__(self, attribute_default=None):
        self._attribute_default = attribute_default
        
    def __getattr__(self, name):
        print(f"{name} not found; creating it and setting it to default...")
        setattr(self, name, self._attribute_default)
        return self._attribute_default

# %%
d = DefaultClass("NotAvailable")
d.test
# Out:
# test not found; creating it and setting it to default...
# 'NotAvailable'

# %%
d.__dict__
# Out:
# {'_attribute_default': 'NotAvailable', 'test': 'NotAvailable'}

# %%
d.age
# Out:
# age not found; creating it and setting it to default...
# 'NotAvailable'

# %%
d.__dict__
# Out:
# {'_attribute_default': 'NotAvailable',
#  'test': 'NotAvailable',
#  'age': 'NotAvailable'}

# %%
d.age
# Out:
# 'NotAvailable'

# %%
 d.age = 18

# %%
d.age
# Out:
# 18

# %%
d.__dict__
# Out:
# {'_attribute_default': 'NotAvailable', 'test': 'NotAvailable', 'age': 18}

# %% [markdown]
# now we can inherit from this class to provide its functionality

# %%
class Person(DefaultClass):
    def __init__(self, name):
        super().__init__("Unavailable")
        self.name = name

# %%
p = Person("Alex")
p.name
# Out:
# 'Alex'

# %%
p.age
# Out:
# age not found; creating it and setting it to default...
# 'Unavailable'

# %% [markdown]
# Another usecase: logging the fact, that nonexisting attribute was requested

# %%
class AttributeNotFoundLogger:
    def __getattr__(self, name):
        err_msg = f"{type(self).__name__} object has no attribute {name}."
        print(f"Log: {err_msg}")
        raise AttributeError(err_msg)

# %%
class Person(AttributeNotFoundLogger):
    def __init__(self, name):
        self.name = name

# %%
p = Person("Alex")

# %%
p.name
# Out:
# 'Alex'

# %%
try:
    p.age  
except AttributeError as err:
    print(err)
# Out:
# Log: Person object has no attribute age.
# Person object has no attribute age.

# %% [markdown]
# let's take a look at `__getattribute__`  method. we should be very careful with infinite recursion

# %% [markdown]
# Example: we want to stop people from accessing `_attributes`

# %%
class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    def __getattribute__(self, name):
        if name.startswith('_'):
            raise AttributeError(f"Forbidden access to {name}")
        return super().__getattribute__( name)

# %%
p = Person("Alex", 19)

# %%
p._name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-5f47c20924e4> in <module>
# ----> 1 p._name
#
# <ipython-input-38-4e06a99e2dd3> in __getattribute__(self, name)
#       6     def __getattribute__(self, name):
#       7         if name.startswith('_'):
# ----> 8             raise AttributeError(f"Forbidden access to {name}")
#       9         return super().__getattribute__( name)
#
# AttributeError: Forbidden access to _name

# %% [markdown]
# but `__dict__` is unavailable too

# %%
p.__dict__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-33b2432b7e42> in <module>
# ----> 1 p.__dict__
#
# <ipython-input-38-4e06a99e2dd3> in __getattribute__(self, name)
#       6     def __getattribute__(self, name):
#       7         if name.startswith('_'):
# ----> 8             raise AttributeError(f"Forbidden access to {name}")
#       9         return super().__getattribute__( name)
#
# AttributeError: Forbidden access to __dict__

# %%
vars(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0c35495ab569> in <module>
# ----> 1 vars(p)
#
# TypeError: vars() argument must have __dict__ attribute

# %% [markdown]
# let's fix it

# %%
class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    def __getattribute__(self, name):
        if name.startswith('_') and not name.startswith('__'):
            raise AttributeError(f"Forbidden access to {name}")
        return super().__getattribute__(name)

# %%
p = Person("Alex", 19)

# %%
p._name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-5f47c20924e4> in <module>
# ----> 1 p._name
#
# <ipython-input-43-09c5dc08c9c2> in __getattribute__(self, name)
#       6     def __getattribute__(self, name):
#       7         if name.startswith('_') and not name.startswith('__'):
# ----> 8             raise AttributeError(f"Forbidden access to {name}")
#       9         return super().__getattribute__( name)
#
# AttributeError: Forbidden access to _name

# %%
p.__dict__
# Out:
# {'_name': 'Alex', '_age': 19}

# %%
vars(p)
# Out:
# {'_name': 'Alex', '_age': 19}

# %% [markdown]
# but we still doesn't have access to name and age. let's work on this

# %% [markdown]
# this won't work:

# %%
class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    def __getattribute__(self, name):
        if name.startswith('_') and not name.startswith('__'):
            raise AttributeError(f"Forbidden access to {name}")
        return super().__getattribute__(name)
    
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self._age

# %%
p = Person("Alex", 19)
p.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-ae9858a124bb> in <module>
#       1 p = Person("Alex", 19)
# ----> 2 p.name
#
# <ipython-input-48-c009e0b709f8> in __getattribute__(self, name)
#       7         if name.startswith('_') and not name.startswith('__'):
#       8             raise AttributeError(f"Forbidden access to {name}")
# ----> 9         return super().__getattribute__(name)
#      10
#      11     @property
#
# <ipython-input-48-c009e0b709f8> in name(self)
#      11     @property
#      12     def name(self):
# ---> 13         return self._name
#      14     @property
#      15     def age(self):
#
# <ipython-input-48-c009e0b709f8> in __getattribute__(self, name)
#       6     def __getattribute__(self, name):
#       7         if name.startswith('_') and not name.startswith('__'):
# ----> 8             raise AttributeError(f"Forbidden access to {name}")
#       9         return super().__getattribute__(name)
#      10
#
# AttributeError: Forbidden access to _name

# %% [markdown]
# let's fix it

# %%
class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    def __getattribute__(self, name):
        if name.startswith('_') and not name.startswith('__'):
            raise AttributeError(f"Forbidden access to {name}")
        return super().__getattribute__(name)
    
    @property
    def name(self):
        return super().__getattribute__('_name')
    @property
    def age(self):
        return super().__getattribute__('_age')

# %%
p = Person("Alex", 19)
p.name
# Out:
# 'Alex'

# %%
p._name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-5f47c20924e4> in <module>
# ----> 1 p._name
#
# <ipython-input-50-3ede99046d3f> in __getattribute__(self, name)
#       6     def __getattribute__(self, name):
#       7         if name.startswith('_') and not name.startswith('__'):
# ----> 8             raise AttributeError(f"Forbidden access to {name}")
#       9         return super().__getattribute__(name)
#      10
#
# AttributeError: Forbidden access to _name

# %% [markdown]
# let's mix it with DefaultClass

# %% [markdown]
# we need to change our defaultClass first

# %%
class DefaultClass:
    def __init__(self, attribute_default=None):
        self._attribute_default = attribute_default
        
    def __getattr__(self, name):
        print(f"{name} not found; creating it and setting it to default...")
        default_value = super().__getattribute__('_attribute_default')
        setattr(self, name, default_value)
        return default_value

# %%
class Person(DefaultClass):
    def __init__(self, name, age):
        super().__init__("NotAvailable")
        if name is not None:
            self._name = name
        if age is not None:    
            self._age = age
        
    def __getattribute__(self, name):
        if name.startswith('_') and not name.startswith('__'):
            raise AttributeError(f"Forbidden access to {name}")
        return super().__getattribute__(name)
    
    @property
    def name(self):
        return super().__getattribute__('_name')
    @property
    def age(self):
        return super().__getattribute__('_age')

# %%
p = Person("Python", 42)
p.name
# Out:
# 'Python'

# %%
p.language
# Out:
# language not found; creating it and setting it to default...
# 'NotAvailable'

# %%
p.__dict__
# Out:
# {'_attribute_default': 'NotAvailable',
#  '_name': 'Python',
#  '_age': 42,
#  'language': 'NotAvailable'}

# %% [markdown]
# what about class attributes? how can we override accessors for class attributes?

# %%
class MetaLogger(type):
    def __getattribute__(self, name):
        print("class __getattribute__ called...")
        return super().__getattribute__(name)
    def __getattr__(self, name):
        print("class __getattr__ called...")
        return "Not Found"

# %%
class Account(metaclass=MetaLogger):
    apr = 10

# %%
Account.apr
# Out:
# class __getattribute__ called...
# 10

# %%
Account.afrfr
# Out:
# class __getattribute__ called...
# class __getattr__ called...
# 'Not Found'

# %% [markdown]
# it doesn't matter if we access callable or attribute, it still runs `__getattribute__`

# %%
class MyClass:
    def __getattribute__(self, name):
        print("class __getattribute__ called...")
        return super().__getattribute__(name)
    
    def __getattr__(self, name):
        print("class __getattr__ called...")
        raise AttributeError(f"{name} not found.")
        
    def say_hello(self):
        return 'hello'

# %%
m = MyClass()

# %%
m.say_hello()
# Out:
# class __getattribute__ called...
# 'hello'

# %%
m.other()
# Out:
# class __getattribute__ called...
# class __getattr__ called...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-5b7a82c5e541> in <module>
# ----> 1 m.other()
#
# <ipython-input-63-30f355dcce97> in __getattr__(self, name)
#       6     def __getattr__(self, name):
#       7         print("class __getattr__ called...")
# ----> 8         raise AttributeError(f"{name} not found.")
#       9
#      10     def say_hello(self):
#
# AttributeError: other not found.
